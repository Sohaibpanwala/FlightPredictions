# %%
import pandas as pd

import requests as re
import json 
from IPython.display import JSON

# %%
from config import ApiKey

# %%
df = pd.read_csv('Heavy_Data/flightsprocessed.csv')

# %%
dates = pd.to_datetime(df['fl_date'])

# %%
df['fl_date_previous'] = dates -  pd.to_timedelta((7), unit='d')

# %%
df.nunique()
# Out:
# Unnamed: 0                         684223
# fl_date                               730
# mkt_unique_carrier                     11
# branded_code_share                     16
# mkt_carrier                            11
# mkt_carrier_fl_num                   7058
# op_unique_carrier                      28
# tail_num                             6419
# op_carrier_fl_num                    7067
# origin_airport_id                     375
# origin                                375
# origin_city_name                      367
# dest_airport_id                       375
# dest                                  375
# dest_city_name                        367
# crs_dep_time                         1349
# dep_time                             1425
# dep_delay                            1060
# taxi_out                              171
# wheels_off                           1400
# wheels_on                            1440
# taxi_in                               155
# ...

# %%
Test = pd.DataFrame.sample(df,910)

# %%
weather_data.isnull().sum().sort_values(ascending=False)
# Out:
# longest_add_gtime     905
# total_add_gtime       905
# first_dep_time        905
# nas_delay             728
# carrier_delay         728
#                      ...
# op_carrier_fl_num       0
# mkt_unique_carrier      0
# tail_num                0
# op_unique_carrier       0
# fl_date                 0
# Length: 68, dtype: int64

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#         Unnamed: 0     fl_date mkt_unique_carrier branded_code_share  \
# 0                0  2018-06-15                 DL       DL_CODESHARE
# 1                1  2019-07-30                 DL       DL_CODESHARE
# 2                2  2018-07-17                 DL       DL_CODESHARE
# 3                3  2019-08-04                 DL       DL_CODESHARE
# 4                4  2019-05-30                 DL       DL_CODESHARE
# ...            ...         ...                ...                ...
# 684218      684218  2018-01-15                 HA                 HA
# 684219      684219  2018-09-24                 HA                 HA
# 684220      684220  2019-07-08                 HA                 HA
# 684221      684221  2019-05-09                 HA                 HA
# 684222      684222  2019-02-04                 HA                 HA
#
#        mkt_carrier  mkt_carrier_fl_num op_unique_carrier tail_num  \
# 0               DL                6230                G7   N378CA
# ...

# %%
Z = [df.fl_date.unique(),df.fl_date_previous.unique()]

# %%
Z = pd.DataFrame(Z)

# %%
Z = Z.T

# %%
Z.columns = ['fl_date','fl_date_previous']

# %%
X1 = df[['fl_date','origin_city_name']]

# %%
X1.sort_values(by='fl_date')
# Out:
#            fl_date                origin_city_name
# 633269  2018-01-01  West Palm Beach/Palm Beach, FL
# 666606  2018-01-01                    San Jose, CA
# 409276  2018-01-01                       Miami, FL
# 110702  2018-01-01                  Pittsburgh, PA
# 490713  2018-01-01                      Newark, NJ
# ...            ...                             ...
# 382564  2019-12-31                     Chicago, IL
# 474987  2019-12-31                      Denver, CO
# 57104   2019-12-31                   St. Louis, MO
# 584581  2019-12-31                       Aspen, CO
# 195498  2019-12-31                  Cincinnati, OH
#
# [684223 rows x 2 columns]

# %%
X2 = X1.sample(1000)

# %%
X2.head()
# Out:
#            fl_date  origin_city_name
# 440901  2019-11-06    Louisville, KY
# 401556  2018-07-16  Philadelphia, PA
# 366334  2019-09-14       Phoenix, AZ
# 302766  2018-07-31     Charlotte, NC
# 655931  2019-06-01          Reno, NV

# %%
X1['add'] = X1['fl_date'] + X1['origin_city_name']

# %%
X1
# Out:
#            fl_date    origin_city_name                           add
# 0       2018-06-15  Raleigh/Durham, NC  2018-06-15Raleigh/Durham, NC
# 1       2019-07-30  Raleigh/Durham, NC  2019-07-30Raleigh/Durham, NC
# 2       2018-07-17  Raleigh/Durham, NC  2018-07-17Raleigh/Durham, NC
# 3       2019-08-04  Raleigh/Durham, NC  2019-08-04Raleigh/Durham, NC
# 4       2019-05-30  Raleigh/Durham, NC  2019-05-30Raleigh/Durham, NC
# ...            ...                 ...                           ...
# 684218  2018-01-15       Pago Pago, TT       2018-01-15Pago Pago, TT
# 684219  2018-09-24       Pago Pago, TT       2018-09-24Pago Pago, TT
# 684220  2019-07-08       Pago Pago, TT       2019-07-08Pago Pago, TT
# 684221  2019-05-09       Pago Pago, TT       2019-05-09Pago Pago, TT
# 684222  2019-02-04       Pago Pago, TT       2019-02-04Pago Pago, TT
#
# [684223 rows x 3 columns]

# %%
X1['add'].nunique()
# Out:
# 115727

# %%
X1['test'] = X1['fl_date'].apply(lambda x: x[:7])
# Out:
# <ipython-input-71-62dceb6b26bd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X1['test'] = X1['fl_date'].apply(lambda x: x[:7])

# %%
X1['test'] = X1['test'].apply(lambda x: x+'-15')
# Out:
# <ipython-input-73-a5347ac2f457>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X1['test'] = X1['test'].apply(lambda x: x+'-15')

# %%
X1['add'] = X1['test'] + X1['origin_city_name']
# Out:
# <ipython-input-75-ae6073b916a5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X1['add'] = X1['test'] + X1['origin_city_name']

# %%
X1['add'].nunique()
# Out:
# 8200

# %%
X1.dtypes
# Out:
# fl_date             object
# origin_city_name    object
# add                 object
# test                object
# dtype: object

# %%
Test
# Out:
#         Unnamed: 0     fl_date mkt_unique_carrier branded_code_share  \
# 671530      671530  2018-09-23                 AS       AS_CODESHARE
# 576677      576677  2019-09-08                 UA       UA_CODESHARE
# 458132      458132  2019-12-30                 AA       AA_CODESHARE
# 324870      324870  2018-01-31                 AA       AA_CODESHARE
# 504388      504388  2018-06-13                 UA       UA_CODESHARE
# ...            ...         ...                ...                ...
# 218259      218259  2019-12-20                 WN                 WN
# 250443      250443  2018-07-15                 WN                 WN
# 354329      354329  2018-08-09                 AA                 AA
# 573121      573121  2019-12-08                 UA       UA_CODESHARE
# 351445      351445  2019-05-25                 AA       AA_CODESHARE
#
#        mkt_carrier  mkt_carrier_fl_num op_unique_carrier tail_num  \
# 671530          AS                2084                QX   N436QX
# ...

# %%
random = Test[:10]

# %%
random
# Out:
#         Unnamed: 0     fl_date mkt_unique_carrier branded_code_share  \
# 671530      671530  2018-09-23                 AS       AS_CODESHARE
# 576677      576677  2019-09-08                 UA       UA_CODESHARE
# 458132      458132  2019-12-30                 AA       AA_CODESHARE
# 324870      324870  2018-01-31                 AA       AA_CODESHARE
# 504388      504388  2018-06-13                 UA       UA_CODESHARE
# 83739        83739  2018-12-09                 DL       DL_CODESHARE
# 85375        85375  2018-01-14                 DL       DL_CODESHARE
# 491929      491929  2018-11-02                 UA       UA_CODESHARE
# 275868      275868  2019-12-09                 WN                 WN
# 484971      484971  2019-09-22                 UA       UA_CODESHARE
#
#        mkt_carrier  mkt_carrier_fl_num op_unique_carrier tail_num  \
# 671530          AS                2084                QX   N436QX
# 576677          UA                3923                ZW   N426AW
# ...

# %%
weather = re.get(f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/weatherdata/history?aggregateHours=24&combinationMethod=aggregate&startDateTime=2018-06-08T00%3A00%3A00&endDateTime=2018-06-15T00%3A00%3A00&maxStations=-1&maxDistance=-1&contentType=json&unitGroup=metric&locationMode=single&key={ApiKey}&dataElements=default&',params=params)

# %%
weather1 = re.get(f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/weatherdata/history?aggregateHours=24&combinationMethod=aggregate&maxStations=-1&maxDistance=-1&contentType=json&unitGroup=metric&locationMode=single&key={ApiKey}&dataElements=default&',params=params)

# %% [markdown]
# Trying out different permutations

# %%
JSON(weather1.json())

# %%
params = {'location': 'Albany, NY','startDateTime':'2018-09-16','endDateTime':'2018-09-23'}

# %%
weather1
# Out:
# <Response [200]>

# %%
i = []

# %%
random.reset_index(inplace=True)

# %%
e = random['fl_date_previous'][0]

# %%
from datetime import datetime

# %%
random['fl_date'][0]
# Out:
# '2018-09-23'

# %%
random['fl_date0'] = random['fl_date_previous'].apply(lambda x: x.date().strftime('%Y-%m-%d'))
# Out:
# <ipython-input-210-18416fcdebbb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   random['fl_date0'] = random['fl_date_previous'].apply(lambda x: x.date().strftime('%Y-%m-%d'))

# %%
random
# Out:
#     index  Unnamed: 0     fl_date mkt_unique_carrier branded_code_share  \
# 0  671530      671530  2018-09-23                 AS       AS_CODESHARE
# 1  576677      576677  2019-09-08                 UA       UA_CODESHARE
# 2  458132      458132  2019-12-30                 AA       AA_CODESHARE
# 3  324870      324870  2018-01-31                 AA       AA_CODESHARE
# 4  504388      504388  2018-06-13                 UA       UA_CODESHARE
# 5   83739       83739  2018-12-09                 DL       DL_CODESHARE
# 6   85375       85375  2018-01-14                 DL       DL_CODESHARE
# 7  491929      491929  2018-11-02                 UA       UA_CODESHARE
# 8  275868      275868  2019-12-09                 WN                 WN
# 9  484971      484971  2019-09-22                 UA       UA_CODESHARE
#
#   mkt_carrier  mkt_carrier_fl_num op_unique_carrier tail_num  \
# 0          AS                2084                QX   N436QX
# ...

# %%
def weather(x):
    r = []
    for i in x.index:
        params = {'location': x['origin_city_name'][i],'startDateTime': x['fl_date'][i],'endDateTime': x['fl_date'][i]}
        weather = re.get(f'https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/weatherdata/history?aggregateHours=24&combinationMethod=aggregate&maxStations=-1&maxDistance=-1&contentType=json&unitGroup=metric&locationMode=single&key={ApiKey}&dataElements=default&',params=params)
        z = weather.json()
        r.append(z)
    return r

# %%
Test['fl_date0'] = Test['fl_date_previous'].apply(lambda x: x.date().strftime('%Y-%m-%d'))

# %%
l = weather(Test)

# %%
t = []
for i in l:
    t.append(i['location']['values'])

# %%
y = pd.DataFrame(t)

# %%
from itertools import chain

# %%
y = pd.DataFrame(list(chain.from_iterable(t)))

# %%
weather_data = pd.concat([Test,y],axis = 1)

# %%
Test.drop(columns=['index','Unnamed: 0'],inplace=True)

# %%
pd.DataFrame.to_csv(weather_data,'weather_data.csv',index=False)

# %%
Test.reset_index(inplace=True)

# %%
weather_data = pd.join
# Out:
#         Unnamed: 0     fl_date mkt_unique_carrier branded_code_share  \
# 671530      671530  2018-09-23                 AS       AS_CODESHARE
# 576677      576677  2019-09-08                 UA       UA_CODESHARE
# 458132      458132  2019-12-30                 AA       AA_CODESHARE
# 324870      324870  2018-01-31                 AA       AA_CODESHARE
# 504388      504388  2018-06-13                 UA       UA_CODESHARE
# ...            ...         ...                ...                ...
# 218259      218259  2019-12-20                 WN                 WN
# 250443      250443  2018-07-15                 WN                 WN
# 354329      354329  2018-08-09                 AA                 AA
# 573121      573121  2019-12-08                 UA       UA_CODESHARE
# 351445      351445  2019-05-25                 AA       AA_CODESHARE
#
#        mkt_carrier  mkt_carrier_fl_num op_unique_carrier tail_num  \
# 671530          AS                2084                QX   N436QX
# ...

# %%
random[0]['origin_city_name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080             try:
# -> 3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-178-9cd0c5b17fd6> in <module>
# ...

# %%
df = random.apply(lambda x: weather(x))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3080             try:
# -> 3081                 return self._engine.get_loc(casted_key)
#    3082             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'origin_city_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-143-473f08f38d7d> in <module>
# ----> 1 df = random.apply(lambda x: weather(x))
#
# ...

# %%
random
# Out:
#         Unnamed: 0     fl_date mkt_unique_carrier branded_code_share  \
# 671530      671530  2018-09-23                 AS       AS_CODESHARE
# 576677      576677  2019-09-08                 UA       UA_CODESHARE
# 458132      458132  2019-12-30                 AA       AA_CODESHARE
# 324870      324870  2018-01-31                 AA       AA_CODESHARE
# 504388      504388  2018-06-13                 UA       UA_CODESHARE
# 83739        83739  2018-12-09                 DL       DL_CODESHARE
# 85375        85375  2018-01-14                 DL       DL_CODESHARE
# 491929      491929  2018-11-02                 UA       UA_CODESHARE
# 275868      275868  2019-12-09                 WN                 WN
# 484971      484971  2019-09-22                 UA       UA_CODESHARE
#
#        mkt_carrier  mkt_carrier_fl_num op_unique_carrier tail_num  \
# 671530          AS                2084                QX   N436QX
# 576677          UA                3923                ZW   N426AW
# ...

# %%
i
# Out:
# [{'temp': 17.4,
#   'maxt': 23.1,
#   'visibility': 14.5,
#   'wspd': 20.4,
#   'datetimeStr': '2018-06-15T00:00:00-04:00',
#   'heatindex': None,
#   'cloudcover': 74.8,
#   'mint': 13.8,
#   'datetime': 1529020800000,
#   'precip': 0.64,
#   'weathertype': 'Mist, Light Drizzle, Light Rain',
#   'snowdepth': 0.0,
#   'humidity': 68.81,
#   'wgust': 44.0,
#   'conditions': 'Rain, Partially cloudy',
#   'windchill': None},
#  {'temp': 17.4,
#   'maxt': 23.1,
#   'visibility': 14.5,
#   'wspd': 20.4,
#   'datetimeStr': '2018-06-15T00:00:00-04:00',
#   'heatindex': None,
#   'cloudcover': 74.8,
#   'mint': 13.8,
#   'datetime': 1529020800000,
#   'precip': 0.64,
#   'weathertype': 'Mist, Light Drizzle, Light Rain',
#   'snowdepth': 0.0,
#   'humidity': 68.81,
#   'wgust': 44.0,
#   'conditions': 'Rain, Partially cloudy',
#   'windchill': None}]

# %%
random['conditions'] = random['origin_city_name'].apply(lambda x: weather(x))
# Out:
# <ipython-input-97-880c8cea074f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   random['conditions'] = random['origin_city_name'].apply(lambda x: weather(x))

# %%
i
# Out:
# [{'temp': 16.9,
#   'maxt': 23.8,
#   'visibility': 16.0,
#   'wspd': 22.3,
#   'datetimeStr': '2018-06-15T00:00:00-07:00',
#   'heatindex': None,
#   'cloudcover': 11.5,
#   'mint': 9.9,
#   'datetime': 1529020800000,
#   'precip': 0.0,
#   'weathertype': 'Mist, Fog, Light Rain',
#   'snowdepth': 0.0,
#   'humidity': 49.09,
#   'wgust': 42.5,
#   'conditions': 'Clear',
#   'windchill': None},
#  {'temp': 17.4,
#   'maxt': 23.1,
#   'visibility': 14.5,
#   'wspd': 20.4,
#   'datetimeStr': '2018-06-15T00:00:00-04:00',
#   'heatindex': None,
#   'cloudcover': 74.8,
#   'mint': 13.8,
#   'datetime': 1529020800000,
#   'precip': 0.64,
#   'weathertype': 'Mist, Light Drizzle, Light Rain',
#   'snowdepth': 0.0,
#   'humidity': 68.81,
#   'wgust': 44.0,
#   'conditions': 'Rain, Partially cloudy',
#   'windchill': None},
#  {'temp': 28.5,
#   'maxt': 33.5,
#   'visibility': 15.3,
#   'wspd': 16.3,
#   'datetimeStr': '2018-06-15T00:00:00-05:00',
#   'heatindex': 37.7,
#   'cloudcover': 34.8,
# ...

# %%
r = pd.DataFrame(i)

# %%
r
# Out:
#    temp  maxt  visibility  wspd                datetimeStr  heatindex  \
# 0  16.9  23.8        16.0  22.3  2018-06-15T00:00:00-07:00        NaN
# 1  17.4  23.1        14.5  20.4  2018-06-15T00:00:00-04:00        NaN
# 2  28.5  33.5        15.3  16.3  2018-06-15T00:00:00-05:00       37.7
# 3  24.7  28.8        16.0  27.7  2018-06-15T00:00:00-04:00       27.7
# 4  15.6  18.2        15.3  35.2  2018-06-15T00:00:00-07:00        NaN
# 5  23.4  29.5        16.0   9.2  2018-06-15T00:00:00-04:00       28.6
# 6  14.7  17.3        15.7  18.0  2018-06-15T00:00:00-04:00        NaN
# 7  22.1  26.4        16.0  33.3  2018-06-15T00:00:00-04:00        NaN
# 8  25.4  31.4        16.0  23.3  2018-06-15T00:00:00-05:00       32.6
# 9  22.1  26.4        16.0  33.3  2018-06-15T00:00:00-04:00        NaN
#
#    cloudcover  mint       datetime  precip                      weathertype  \
# 0        11.5   9.9  1529020800000    0.00            Mist, Fog, Light Rain
# ...

# %%
#X2['origin_city_name'].apply(lambda x: print(x))

# %%
#X1['origin_city_name'].apply(lambda x: print(x))

# %%
Z1 = pd.merge(Z,df,how='inner',)
# Out:
#        fl_date fl_date_previous
# 0   2018-06-15       2018-06-08
# 1   2019-07-30       2019-07-23
# 2   2018-07-17       2018-07-10
# 3   2019-08-04       2019-07-28
# 4   2019-05-30       2019-05-23
# ..         ...              ...
# 725 2019-01-19       2019-01-12
# 726 2019-06-05       2019-05-29
# 727 2018-01-27       2018-01-20
# 728 2018-12-24       2018-12-17
# 729 2018-09-30       2018-09-23
#
# [730 rows x 2 columns]

# %%
z = weather.json()

# %%
JSON(z)

# %%
z['location']['values'][-1]
# Out:
# {'temp': 25.1,
#  'maxt': 29.6,
#  'visibility': 14.2,
#  'wspd': 19.3,
#  'datetimeStr': '2018-06-15T00:00:00-04:00',
#  'heatindex': 30.0,
#  'cloudcover': 66.9,
#  'mint': 21.2,
#  'datetime': 1529020800000,
#  'precip': 0.0,
#  'weathertype': 'Mist, Fog',
#  'snowdepth': 0.0,
#  'humidity': 73.75,
#  'wgust': 33.5,
#  'conditions': 'Partially cloudy',
#  'windchill': None}

# %%
z
# Out:
# {'columns': {'temp': {'id': 'temp',
#    'name': 'Temperature',
#    'type': 2,
#    'unit': 'degC'},
#   'maxt': {'id': 'maxt',
#    'name': 'Maximum Temperature',
#    'type': 2,
#    'unit': 'degC'},
#   'visibility': {'id': 'visibility',
#    'name': 'Visibility',
#    'type': 2,
#    'unit': 'km'},
#   'wspd': {'id': 'wspd', 'name': 'Wind Speed', 'type': 2, 'unit': 'kph'},
#   'heatindex': {'id': 'heatindex',
#    'name': 'Heat Index',
#    'type': 2,
#    'unit': 'degC'},
#   'cloudcover': {'id': 'cloudcover',
#    'name': 'Cloud Cover',
#    'type': 2,
#    'unit': '%'},
#   'mint': {'id': 'mint',
#    'name': 'Minimum Temperature',
#    'type': 2,
#    'unit': 'degC'},
#   'datetime': {'id': 'datetime', 'name': 'Date time', 'type': 3, 'unit': None},
#   'precip': {'id': 'precip', 'name': 'Precipitation', 'type': 2, 'unit': 'mm'},
#   'weathertype': {'id': 'weathertype',
#    'name': 'Weather Type',
#    'type': 1,
#    'unit': None},
#   'snowdepth': {'id': 'snowdepth',
# ...
